# %% [markdown]
# <img src="http://imgur.com/1ZcRyrc.png" style="float: left; margin: 20px; height: 55px">
#
# # Project 1: Standardized Test Analysis

# %% [raw]
# Feedback:
# - Problem statement to be more clearly defined
# - More evidence is needed to support the arguments
# - Suggest using external data to strengthen the arguments
# - Recommend more elaboration after charts and tables to highlight the key messages
# - Visualisation: some charts are too wide, not ideal for understanding

# %% [markdown]
# ---
# # Part 1
#
# Part 1 requires knowledge of basic Python.
#
# ---

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# #### To improve the uptake of standardized tests among the states, particularly in the midwest.

# %% [markdown]
# ### Contents:
# - [Background](#Background)
# - [Data Import & Cleaning](#Data-Import-and-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-Data)
# - [Conclusions and Recommendations](#Conclusions-and-Recommendations)

# %% [markdown]
# ## Background

# %% [markdown]
# The SAT and ACT are standardized tests that many colleges and universities in the United States require for their admissions process. This score is used along with other materials such as grade point average (GPA) and essay responses to determine whether or not a potential student will be accepted to the university.
#
# The SAT has two sections of the test: Evidence-Based Reading and Writing and Math ([*source*](https://www.princetonreview.com/college/sat-sections)). The ACT has 4 sections: English, Mathematics, Reading, and Science, with an additional optional writing section ([*source*](https://www.act.org/content/act/en/products-and-services/the-act/scores/understanding-your-scores.html)). They have different score ranges, which you can read more about on their websites or additional outside sources (a quick Google search will help you understand the scores for each test):
# * [SAT](https://collegereadiness.collegeboard.org/sat)
# * [ACT](https://www.act.org/content/act/en.html)
#
# Standardized tests have long been a controversial topic for students, administrators, and legislators. Since the 1940's, an increasing number of colleges have been using scores from sudents' performances on tests like the SAT and the ACT as a measure for college readiness and aptitude ([*source*](https://www.minotdailynews.com/news/local-news/2017/04/a-brief-history-of-the-sat-and-act/)). Supporters of these tests argue that these scores can be used as an objective measure to determine college admittance. Opponents of these tests claim that these tests are not accurate measures of students potential or ability and serve as an inequitable barrier to entry. Lately, more and more schools are opting to drop the SAT/ACT requirement for their Fall 2021 applications ([*read more about this here*](https://www.cnn.com/2020/04/14/us/coronavirus-colleges-sat-act-test-trnd/index.html)).

# %% [markdown]
# ### Choose your Data
#
# There are 10 datasets included in the [`data`](./data/) folder for this project. You are required to pick **at least two** of these to complete your analysis. Feel free to use more than two if you would like, or add other relevant datasets you find online.
#
# * [`act_2017.csv`](./data/act_2017.csv): 2017 ACT Scores by State
# * [`act_2018.csv`](./data/act_2018.csv): 2018 ACT Scores by State
# * [`act_2019.csv`](./data/act_2019.csv): 2019 ACT Scores by State
# * [`sat_2017.csv`](./data/sat_2017.csv): 2017 SAT Scores by State
# * [`sat_2018.csv`](./data/sat_2018.csv): 2018 SAT Scores by State
# * [`sat_2019.csv`](./data/sat_2019.csv): 2019 SAT Scores by State

# %%
act17 = '../data/act_2017.csv'
act18 = '../data/act_2018.csv'
act19 = '../data/act_2019.csv'
sat17 = '../data/sat_2017.csv'
sat18 = '../data/sat_2018.csv'
sat19 = '../data/sat_2019.csv'

# %% [markdown]
# ### Coding Challenges
#
# 1. Manually calculate mean:
#
#     Write a function that takes in values and returns the mean of the values. Create a list of numbers that you test on your function to check to make sure your function works!
#
#     *Note*: Do not use any mean methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
list1 = [3,5,10,21,94,82,34,6,15,65,74] #example list to be used
def find_mean(samples):
    sum = 0
    for i in samples:
        sum += i
    return sum/len(samples)
find_mean(list1)
# Out:
# 37.18181818181818

# %% [markdown]
# 2. Manually calculate standard deviation:
#
#     The formula for standard deviation is below:
#
#     $$\sigma = \sqrt{\frac{1}{n}\sum_{i=1}^n(x_i - \mu)^2}$$
#
#     Where $x_i$ represents each value in the dataset, $\mu$ represents the mean of all values in the dataset and $n$ represents the number of values in the dataset.
#
#     Write a function that takes in values and returns the standard deviation of the values using the formula above. Hint: use the function you wrote above to calculate the mean! Use the list of numbers you created above to test on your function.
#
#     *Note*: Do not use any standard deviation methods built-in to any Python libraries to do this! This should be done without importing any additional libraries.

# %%
# Code:
def standard_deviation(samples):
    sigma= 0
    for i in samples:
        sigma += (i-find_mean(samples))**2
    return (sigma/len(samples))**0.5

print(standard_deviation(list1))
# Out:
# 33.09165833317619

# %% [markdown]
# 3. Data cleaning function:
#
#     Write a function that takes in a string that is a number and a percent symbol (ex. '50%', '30.5%', etc.) and converts this to a float that is the decimal approximation of the percent. For example, inputting '50%' in your function should return 0.5, '30.5%' should return 0.305, etc. Make sure to test your function to make sure it works!
#
# You will use these functions later on in the project!

# %%
import re
import numpy as np
def float_from_percent(x):
    x=str(x)
    regex = r'\d{1,3}\.?\d*'
    if re.match(regex, x) is None:
        return np.nan
    else:
        return float(re.match(regex, x)[0])

# %%
float_from_percent('10%')
# Out:
# 10.0

# %% [markdown]
# ---
# # Part 2
#
# Part 2 requires knowledge of Pandas, EDA, data cleaning, and data visualization.
#
# ---

# %% [markdown]
# *All libraries used should be added here*

# %%
# Imports:
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Classification of US States by Region
northeast = ['Maine', 'New Hampshire', 'Vermont', 'Massachusetts', 'Rhode Island', 'Connecticut', 'New York', 'New Jersey', 'Pennsylvania']
south = ['Delaware', 'Maryland', 'Virginia', 'West Virginia', 'Kentucky', 'North Carolina', 'South Carolina', 'Tennessee', 'Georgia', 'Florida', 'Alabama', 'Mississippi', 'Arkansas', 'Louisiana', 'Texas', 'Oklahoma']
midwest = ['Illinois','Michigan','Indiana','Ohio','Wisconsin','Minnesota','Iowa','Missouri','North Dakota','South Dakota','Nebraska','Kansas']
west = ['Montana', 'Idaho', 'Wyoming', 'Colorado', 'New Mexico', 'Arizona', 'Utah', 'Nevada', 'California', 'Oregon', 'Washington', 'Alaska', 'Hawaii']

# %% [markdown]
# ## Data Import and Cleaning

# %% [markdown]
# ### Data Import & Cleaning
#
# Import the datasets that you selected for this project and go through the following steps at a minimum. You are welcome to do further cleaning as you feel necessary:
# 1. Display the data: print the first 5 rows of each dataframe to your Jupyter notebook.
# 2. Check for missing values.
# 3. Check for any obvious issues with the observations (keep in mind the minimum & maximum possible values for each test/subtest).
# 4. Fix any errors you identified in steps 2-3.
# 5. Display the data types of each feature.
# 6. Fix any incorrect data types found in step 5.
#     - Fix any individual values preventing other columns from being the appropriate type.
#     - If your dataset has a column of percents (ex. '50%', '30.5%', etc.), use the function you wrote in Part 1 (coding challenges, number 3) to convert this to floats! *Hint*: use `.map()` or `.apply()`.
# 7. Rename Columns.
#     - Column names should be all lowercase.
#     - Column names should not contain spaces (underscores will suffice--this allows for using the `df.column_name` method to access columns in addition to `df['column_name']`).
#     - Column names should be unique and informative.
# 8. Drop unnecessary rows (if needed).
# 9. Merge dataframes that can be merged.
# 10. Perform any additional cleaning that you feel is necessary.
# 11. Save your cleaned and merged dataframes as csv files.

# %%
#Preparing data for ACT'17
df_act17 = pd.read_csv(act17)
df_act17.head()
# Out:
#       State Participation  English  Math  Reading  Science Composite
# 0  National           60%     20.3  20.7     21.4     21.0      21.0
# 1   Alabama          100%     18.9  18.4     19.7     19.4      19.2
# 2    Alaska           65%     18.7  19.8     20.4     19.9      19.8
# 3   Arizona           62%     18.6  19.8     20.1     19.8      19.7
# 4  Arkansas          100%     18.9  19.0     19.7     19.5      19.4

# %%
df_act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     object
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     object
# dtypes: float64(4), object(3)
# memory usage: 3.0+ KB

# %% [markdown]
# <font color = blue><p>
# - Here we can see that Participation and Composite which needs to be in float Dtype are currently objects.

# %%
#applying function on Participation and Composite to parse for percentages as float
df_act17['Participation'] = df_act17['Participation'].map(float_from_percent)/100
df_act17['Composite'] = df_act17['Composite'].map(float_from_percent)
df_act17.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  51 non-null     float64
#  2   English        52 non-null     float64
#  3   Math           52 non-null     float64
#  4   Reading        52 non-null     float64
#  5   Science        52 non-null     float64
#  6   Composite      52 non-null     float64
# dtypes: float64(6), object(1)
# memory usage: 3.0+ KB

# %%
# Data of Midwest ACT'17
df_act17.loc[df_act17['State'].isin(midwest)]
# Out:
#            State  Participation  English  Math  Reading  Science  Composite
# 14      Illinois           0.93     21.0  21.2     21.6     21.3       21.4
# 15       Indiana           0.35     22.0  22.4     23.2     22.3       22.6
# 16          Iowa           0.67     21.2  21.3     22.6     22.1       21.9
# 17        Kansas           0.73     21.1  21.3     22.3     21.7       21.7
# 23      Michigan           0.29     24.1  23.7     24.5     23.8       24.1
# 24     Minnesota           1.00     20.4  21.5     21.8     21.6       21.5
# 26      Missouri           1.00     19.8  19.9     20.8     20.5       20.4
# 28      Nebraska           0.84     20.9  20.9     21.9     21.5       21.4
# 35  North Dakota           0.98     19.0  20.4     20.5     20.6       20.3
# 36          Ohio           0.75     21.2  21.6     22.5     22.0       22.0
# 42  South Dakota           0.80     20.7  21.5     22.3     22.0       21.8
# ...

# %%
# Repeat Process for ACT'18 & ACT'19

df_act18 = pd.read_csv(act18)
df_act19 = pd.read_csv(act19)
print(df_act18.head())
print(df_act18.head())

#There is only data for 'Participation' and 'Composite' as opposed to ACT'17 data
# Out:
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7
#         State Participation  Composite
# 0     Alabama          100%       19.1
# 1      Alaska           33%       20.8
# 2     Arizona           66%       19.2
# 3    Arkansas          100%       19.4
# 4  California           27%       22.7

# %%
df_act18.drop(20,inplace=True) #remove duplicate entry of Maine
df_act18.loc[df_act18['State']=='District of columbia'] = 'District of Columbia' #fix typo error
df_act18['Participation'] = df_act18['Participation'].map(float_from_percent)/100
df_act18['Composite'] = df_act18['Composite'].map(float_from_percent)
df_act18.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 51 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          51 non-null     object
#  1   Participation  50 non-null     float64
#  2   Composite      50 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.6+ KB

# %%
df_act19['Participation'] = df_act19['Participation'].map(float_from_percent)/100
df_act19['Composite'] = df_act19['Composite'].map(float_from_percent)
df_act19.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   State          52 non-null     object
#  1   Participation  52 non-null     float64
#  2   Composite      52 non-null     float64
# dtypes: float64(2), object(1)
# memory usage: 1.3+ KB

# %%
# Data of Midwest ACT'18
df_act18.loc[df_act18['State'].isin(midwest)]
# Out:
#            State  Participation  Composite
# 13      Illinois           0.43       23.9
# 14       Indiana           0.32       22.5
# 15          Iowa           0.68       21.8
# 16        Kansas           0.71       21.6
# 23      Michigan           0.22       24.2
# 24     Minnesota           0.99       21.3
# 26      Missouri           1.00       20.0
# 28      Nebraska           1.00       20.1
# 35  North Dakota           0.98       20.3
# 36          Ohio           1.00       20.3
# 42  South Dakota           0.77       21.9
# 50     Wisconsin           1.00       20.5

# %%
# Data of Midwest ACT'19
df_act19.loc[df_act19['State'].isin(midwest)]
# Out:
#            State  Participation  Composite
# 13      Illinois           0.35       24.3
# 14       Indiana           0.29       22.5
# 15          Iowa           0.66       21.6
# 16        Kansas           0.72       21.2
# 22      Michigan           0.19       24.4
# 23     Minnesota           0.95       21.4
# 25      Missouri           0.82       20.8
# 27      Nebraska           1.00       20.0
# 34  North Dakota           0.96       19.9
# 35          Ohio           1.00       20.0
# 41  South Dakota           0.75       21.6
# 49     Wisconsin           1.00       20.3

# %%
# Repeat process for SAT'17 to SAT'19 datas
df_sat17=pd.read_csv(sat17)
df_sat18=pd.read_csv(sat18)
df_sat19=pd.read_csv(sat19)
print(df_sat17.head())
print(df_sat18.head())
print(df_sat19.head())
# Out:
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            5%                                 593   572   1165
# 1      Alaska           38%                                 547   533   1080
# 2     Arizona           30%                                 563   553   1116
# 3    Arkansas            3%                                 614   594   1208
# 4  California           53%                                 531   524   1055
#         State Participation  Evidence-Based Reading and Writing  Math  Total
# 0     Alabama            6%                                 595   571   1166
# 1      Alaska           43%                                 562   544   1106
# 2     Arizona           29%                                 577   572   1149
# 3    Arkansas            5%                                 592   576   1169
# 4  California           60%                                 540   536   1076
# ...

# %%
print(df_sat17.info())
print(df_sat18.info())
print(df_sat19.info())

#Only 'Participation' needs to be corrected
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
#  2   Evidence-Based Reading and Writing  51 non-null     int64
#  3   Math                                51 non-null     int64
#  4   Total                               51 non-null     int64
# dtypes: int64(3), object(2)
# memory usage: 2.1+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   State                               51 non-null     object
#  1   Participation                       51 non-null     object
# ...

# %%
df_sat17['Participation'] = df_sat17['Participation'].map(float_from_percent)/100

df_sat18['Participation'] = df_sat18['Participation'].map(float_from_percent)/100

df_sat19.rename(columns={'Participation Rate':"Participation"},inplace=True)

df_sat19['Participation'] = df_sat19['Participation'].map(float_from_percent)/100

# %%
# Data of Midwest SAT'17
df_sat17.loc[df_sat17['State'].isin(midwest)]
# Out:
#            State  Participation  Evidence-Based Reading and Writing  Math  \
# 13      Illinois           0.09                                 559   556
# 14       Indiana           0.63                                 542   532
# 15          Iowa           0.02                                 641   635
# 16        Kansas           0.04                                 632   628
# 22      Michigan           1.00                                 509   495
# 23     Minnesota           0.03                                 644   651
# 25      Missouri           0.03                                 640   631
# 27      Nebraska           0.03                                 629   625
# 34  North Dakota           0.02                                 635   621
# 35          Ohio           0.12                                 578   570
# 41  South Dakota           0.03                                 612   603
# 49     Wisconsin           0.03                                 642   649
#
# ...

# %%
# Data of Midwest SAT'18
df_sat18.loc[df_sat18['State'].isin(midwest)]
# Out:
#            State  Participation  Evidence-Based Reading and Writing  Math  \
# 13      Illinois           0.99                                 513   506
# 14       Indiana           0.63                                 542   532
# 15          Iowa           0.03                                 634   631
# 16        Kansas           0.04                                 633   631
# 22      Michigan           1.00                                 511   499
# 23     Minnesota           0.04                                 643   655
# 25      Missouri           0.04                                 633   629
# 27      Nebraska           0.03                                 629   623
# 34  North Dakota           0.02                                 640   643
# 36          Ohio           0.18                                 552   547
# 41  South Dakota           0.03                                 622   618
# 49     Wisconsin           0.03                                 641   653
#
# ...

# %%
# Data of Midwest SAT'19
df_sat19.loc[df_sat19['State'].isin(midwest)]
# Out:
#            State  Participation  EBRW  Math  Total
# 13      Illinois           1.00   509   504   1013
# 14       Indiana           0.66   543   537   1080
# 15          Iowa           0.03   622   622   1244
# 16        Kansas           0.04   618   623   1241
# 22      Michigan           1.00   507   496   1003
# 23     Minnesota           0.04   636   648   1284
# 25      Missouri           0.04   622   615   1236
# 27      Nebraska           0.03   628   631   1260
# 34  North Dakota           0.02   627   636   1263
# 35          Ohio           0.19   550   548   1097
# 42  South Dakota           0.03   633   635   1268
# 51     Wisconsin           0.03   635   648   1283

# %%
#formating data of ACT'17
df_act17.drop(['English','Math','Reading','Science'],axis=1,inplace=True)
df_act17.rename({'Participation':'act_part_17','Composite':'act_comp_17'},axis=1,inplace=True)
df_act17.head()
# Out:
#       State  act_part_17  act_comp_17
# 0  National          NaN         21.0
# 1   Alabama         1.00         19.2
# 2    Alaska         0.65         19.8
# 3   Arizona         0.62         19.7
# 4  Arkansas         1.00         19.4

# %%
#formating data of ACT'18
df_act18.rename({'Participation':'act_part_18','Composite':'act_comp_18'},axis=1,inplace=True)
df_act18.head()
# Out:
#         State  act_part_18  act_comp_18
# 0     Alabama         1.00         19.1
# 1      Alaska         0.33         20.8
# 2     Arizona         0.66         19.2
# 3    Arkansas         1.00         19.4
# 4  California         0.27         22.7

# %%
#formating data of ACT'19
df_act19.rename({'Participation':'act_part_19','Composite':'act_comp_19'},axis=1,inplace=True)
df_act19.head()
# Out:
#         State  act_part_19  act_comp_19
# 0     Alabama         1.00         18.9
# 1      Alaska         0.38         20.1
# 2     Arizona         0.73         19.0
# 3    Arkansas         1.00         19.3
# 4  California         0.23         22.6

# %%
#formating data of SAT'17
df_sat17.drop(['Evidence-Based Reading and Writing','Math'],axis=1,inplace=True)
df_sat17.rename({'Participation':'sat_part_17','Total':'sat_total_17'},axis=1,inplace=True)
df_sat17.head()
# Out:
#         State  sat_part_17  sat_total_17
# 0     Alabama         0.05          1165
# 1      Alaska         0.38          1080
# 2     Arizona         0.30          1116
# 3    Arkansas         0.03          1208
# 4  California         0.53          1055

# %%
#formating data of SAT'18
df_sat18.drop(['Evidence-Based Reading and Writing','Math'],axis=1,inplace=True)
df_sat18.rename({'Participation':'sat_part_18','Total':'sat_total_18'},axis=1,inplace=True)
df_sat18.head()
# Out:
#         State  sat_part_18  sat_total_18
# 0     Alabama         0.06          1166
# 1      Alaska         0.43          1106
# 2     Arizona         0.29          1149
# 3    Arkansas         0.05          1169
# 4  California         0.60          1076

# %%
#formating data of SAT'19
df_sat19.drop(['EBRW','Math'],axis=1,inplace=True)
df_sat19.rename({'Participation':'sat_part_19','Total':'sat_total_19'},axis=1,inplace=True)
df_sat19.head()
# Out:
#         State  sat_part_19  sat_total_19
# 0     Alabama         0.07          1143
# 1      Alaska         0.41          1097
# 2     Arizona         0.31          1134
# 3    Arkansas         0.06          1141
# 4  California         0.63          1065

# %%
#Combine all data into one dataframe
to_merge = [df_act17, df_act18, df_act19, df_sat17, df_sat18, df_sat19]
df = df_act17
for x in to_merge[1:]:
    df = pd.merge(how='outer',left=df,right=x,on='State')
df.drop([0],inplace=True) #drop 'national' row
df.head()
# Out:
#         State  act_part_17  act_comp_17  act_part_18  act_comp_18  \
# 1     Alabama         1.00         19.2         1.00         19.1
# 2      Alaska         0.65         19.8         0.33         20.8
# 3     Arizona         0.62         19.7         0.66         19.2
# 4    Arkansas         1.00         19.4         1.00         19.4
# 5  California         0.31         22.8         0.27         22.7
#
#    act_part_19  act_comp_19  sat_part_17  sat_total_17  sat_part_18  \
# 1         1.00         18.9         0.05        1165.0         0.06
# 2         0.38         20.1         0.38        1080.0         0.43
# 3         0.73         19.0         0.30        1116.0         0.29
# 4         1.00         19.3         0.03        1208.0         0.05
# 5         0.23         22.6         0.53        1055.0         0.60
#
#    sat_total_18  sat_part_19  sat_total_19
# 1        1166.0         0.07        1143.0
# 2        1106.0         0.41        1097.0
# ...

# %%
df.isnull().sum()
# Out:
# State           0
# act_part_17     2
# act_comp_17     2
# act_part_18     3
# act_comp_18     3
# act_part_19     2
# act_comp_19     2
# sat_part_17     2
# sat_total_17    2
# sat_part_18     2
# sat_total_18    2
# sat_part_19     2
# sat_total_19    0
# dtype: int64

# %% [markdown]
# <font color = blue><p>
# - Upon closer inspection, most of the null entries are from non-State US territories.
# - Therefore in this exercise, I have decided to drop them (DC, Puerto Rico & Virgin Islands)

# %%
df.dropna(inplace=True)
df.info()
# Exactly 50 States!
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50 entries, 1 to 51
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   State         50 non-null     object
#  1   act_part_17   50 non-null     float64
#  2   act_comp_17   50 non-null     float64
#  3   act_part_18   50 non-null     float64
#  4   act_comp_18   50 non-null     float64
#  5   act_part_19   50 non-null     float64
#  6   act_comp_19   50 non-null     float64
#  7   sat_part_17   50 non-null     float64
#  8   sat_total_17  50 non-null     float64
#  9   sat_part_18   50 non-null     float64
#  10  sat_total_18  50 non-null     float64
#  11  sat_part_19   50 non-null     float64
#  12  sat_total_19  50 non-null     float64
# dtypes: float64(12), object(1)
# memory usage: 5.5+ KB

# %%
# Create dictionary of key region against state values:
keys = ['Midwest','West','Northeast','South']
values = [midwest,west,northeast,south]
region_options = dict(zip(keys,values))
region_options['Midwest'][:5] #check
# Out:
# ['Illinois', 'Michigan', 'Indiana', 'Ohio', 'Wisconsin']

# %%
# Create new list for column 'region'
region=[]
for x in df['State']:
    for i,j in region_options.items():
        if x in j:
            region.append(i)

# %%
df['region'] = region
df[['State','region']].head()
# Out:
#         State region
# 1     Alabama  South
# 2      Alaska   West
# 3     Arizona   West
# 4    Arkansas  South
# 5  California   West

# %% [markdown]
# ### Data Dictionary
#
# Now that we've fixed our data, and given it appropriate names, let's create a [data dictionary](http://library.ucmerced.edu/node/10249).
#
# A data dictionary provides a quick overview of features/variables/columns, alongside data types and descriptions. The more descriptive you can be, the more useful this document is.
#
# Example of a Fictional Data Dictionary Entry:
#
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |**county_pop**|*integer*|2010 census|The population of the county (units in thousands, where 2.5 represents 2500 people).|
# |**per_poverty**|*float*|2010 census|The percent of the county over the age of 18 living below the 200% of official US poverty rate (units percent to two decimal places 98.10 means 98.1%)|
#
# [Here's a quick link to a short guide for formatting markdown in Jupyter notebooks](https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/Working%20With%20Markdown%20Cells.html).
#
# Provided is the skeleton for formatting a markdown table, with columns headers that will help you create a data dictionary to quickly summarize your data, as well as some examples. **This would be a great thing to copy and paste into your custom README for this project.**
#
# *Note*: if you are unsure of what a feature is, check the source of the data! This can be found in the README.

# %% [markdown]
# |Feature|Type|Dataset|Description|
# |---|---|---|---|
# |State|object|ACT/SAT|List of 50 States in the USA|
# |act_part_17|float|ACT|% of ACT State participation in 2017|
# |act_comp_17|float|ACT|State Average Composite Score of ACT in 2017|
# |act_part_18|float|ACT|% of ACT State participation in 2018|
# |act_comp_18|float|ACT|State Average Composite Score of ACT in 2018|
# |act_part_19|float|ACT|% of ACT State participation in 2019|
# |act_comp_19|float|ACT|State Average Composite Score of ACT in 2019|
# |sat_part_17|float|SAT|% of SAT State participation in 2017|
# |sat_total_17|float|SAT|State Average Total Score of SAT in 2017|
# |sat_part_18|float|SAT|% of SAT State participation in 2018|
# |sat_total_18|float|SAT|State Average Total Score of SAT in 2018|
# |sat_part_19|float|SAT|% of SAT State participation in 2017|
# |sat_total_19|float|SAT|State Average Total Score of SAT in 2019|
# |region|object|external|Classification of state by region

# %% [markdown]
# ## Exploratory Data Analysis
#
# Complete the following steps to explore your data. You are welcome to do more EDA than the steps outlined here as you feel necessary:
# 1. Summary Statistics.
# 2. Use a **dictionary comprehension** to apply the standard deviation function you create in part 1 to each numeric column in the dataframe.  **No loops**.
#     - Assign the output to variable `sd` as a dictionary where:
#         - Each column name is now a key
#         - That standard deviation of the column is the value
#         - *Example Output :* `{'ACT_Math': 120, 'ACT_Reading': 120, ...}`
# 3. Investigate trends in the data.
#     - Using sorting and/or masking (along with the `.head()` method to avoid printing our entire dataframe), consider questions relevant to your problem statement. Some examples are provided below (but feel free to change these questions for your specific problem):
#         - Which states have the highest and lowest participation rates for the 2017, 2019, or 2019 SAT and ACT?
#         - Which states have the highest and lowest mean total/composite scores for the 2017, 2019, or 2019 SAT and ACT?
#         - Do any states with 100% participation on a given test have a rate change year-to-year?
#         - Do any states show have >50% participation on *both* tests each year?
#         - Which colleges have the highest median SAT and ACT scores for admittance?
#         - Which California school districts have the highest and lowest mean test scores?
#     - **You should comment on your findings at each step in a markdown cell below your code block**. Make sure you include at least one example of sorting your dataframe by a column, and one example of using boolean filtering (i.e., masking) to select a subset of the dataframe.

# %%
#Code:
# key = column name
# value = column data series
sd = {x: standard_deviation(df[x]) for x in df.columns[1:13]}
sd
# Out:
# {'act_part_17': 0.3178794740149165,
#  'act_comp_17': 1.9840977798485642,
#  'act_part_18': 0.33771254048376703,
#  'act_comp_18': 2.090091864009809,
#  'act_part_19': 0.3430510166141473,
#  'act_comp_19': 2.175183670405789,
#  'sat_part_17': 0.3421286307808805,
#  'sat_total_17': 89.00941298536914,
#  'sat_part_18': 0.36724754594142633,
#  'sat_total_18': 91.91248881408882,
#  'sat_part_19': 0.38212228409240934,
#  'sat_total_19': 95.17612305615312}

# %% [markdown]
# ### Which States have the Highest and Lowest Participation Rates? ###

# %%
#States with highest & lowest ACT participation in '17

print(df[['State','act_part_17']].nlargest(3,'act_part_17'))
print(df[['State','act_part_17']].nsmallest(3,'act_part_17'))
# Out:
#       State  act_part_17
# 1   Alabama          1.0
# 4  Arkansas          1.0
# 6  Colorado          1.0
#             State  act_part_17
# 20          Maine         0.08
# 8        Delaware         0.18
# 30  New Hampshire         0.18

# %%
#Seems like many states have 100% ACT participation in 2017
df.act_part_17.value_counts().head()
# 17 out of 50 states have 100% participation
# Out:
# 1.00    17
# 0.29     5
# 0.31     3
# 0.18     2
# 0.73     2
# Name: act_part_17, dtype: int64

# %%
# How about ACT 2018
print(df[['State','act_part_18']].nlargest(3,'act_part_18'))
print(df[['State','act_part_18']].nsmallest(3,'act_part_18'))
# Out:
#        State  act_part_18
# 1    Alabama          1.0
# 4   Arkansas          1.0
# 18  Kentucky          1.0
#             State  act_part_18
# 20          Maine         0.07
# 40   Rhode Island         0.15
# 30  New Hampshire         0.16

# %%
# Similarly, to check for no. of states with 100% participation:
df.act_part_18.value_counts().head()
# 17 out of 50 states, just like 2017
# Out:
# 1.00    17
# 0.24     3
# 0.27     2
# 0.31     2
# 0.66     2
# Name: act_part_18, dtype: int64

# %%
# And for ACT 2018:
print(df[['State','act_part_19']].nlargest(3,'act_part_19'))
print(df[['State','act_part_19']].nsmallest(3,'act_part_19'))
df.act_part_19.value_counts().head()
# 15 out of 50 states have 100% participation. Seems like it's dropping.
# Out:
#        State  act_part_19
# 1    Alabama          1.0
# 4   Arkansas          1.0
# 18  Kentucky          1.0
#            State  act_part_19
# 20         Maine         0.06
# 40  Rhode Island         0.12
# 8       Delaware         0.13
# 1.00    15
# 0.21     2
# 0.49     2
# 0.22     2
# 0.78     1
# Name: act_part_19, dtype: int64

# %%
# Checking for SAT '17
print(df[['State','sat_part_17']].nlargest(3,'sat_part_17'))
print(df[['State','sat_part_17']].nsmallest(3,'sat_part_17'))
df.sat_part_17.value_counts().head()
# only 3 states have 100% participation
# Out:
#           State  sat_part_17
# 7   Connecticut          1.0
# 8      Delaware          1.0
# 23     Michigan          1.0
#            State  sat_part_17
# 16          Iowa         0.02
# 25   Mississippi         0.02
# 35  North Dakota         0.02
# 0.03    8
# 1.00    3
# 0.02    3
# 0.04    3
# 0.11    2
# Name: sat_part_17, dtype: int64

# %%
# How about SAT '18?
print(df[['State','sat_part_18']].nlargest(3,'sat_part_18'))
print(df[['State','sat_part_18']].nsmallest(3,'sat_part_18'))
df.sat_part_18.value_counts().head()
# only 5 states have 100% participation, 2 more than the previous year
# Out:
#          State  sat_part_18
# 6     Colorado          1.0
# 7  Connecticut          1.0
# 8     Delaware          1.0
#            State  sat_part_18
# 35  North Dakota         0.02
# 16          Iowa         0.03
# 25   Mississippi         0.03
# 0.04    6
# 0.03    6
# 1.00    5
# 0.70    2
# 0.99    2
# Name: sat_part_18, dtype: int64

# %%
# And Finally, SAT '18?
print(df[['State','sat_part_19']].nlargest(3,'sat_part_19'))
print(df[['State','sat_part_19']].nsmallest(3,'sat_part_19'))
df.sat_part_19.value_counts().head()
# only 8 states have 100% participation, 3 more than the previous year
# Out:
#          State  sat_part_19
# 6     Colorado          1.0
# 7  Connecticut          1.0
# 8     Delaware          1.0
#            State  sat_part_19
# 35  North Dakota         0.02
# 16          Iowa         0.03
# 25   Mississippi         0.03
# 1.00    8
# 0.03    6
# 0.04    5
# 0.68    3
# 0.70    2
# Name: sat_part_19, dtype: int64

# %% [markdown]
# <font color = 'blue'><p>
# - Seems like ACT is the more dominant standardized test in terms of 100% State Participation.

# %% [markdown]
# ### Let's compare by region

# %% [markdown]
# #### ACT Participation by Region over the Years

# %%
act_part = ['act_part_17','act_part_18','act_part_19']
regions = ['Midwest','West','Northeast','South']
for j in regions:    
    for i in act_part:
        print(df.loc[df['region']==j,['State','region',i]].sort_values(i,ascending=False))
        print('\n')
# Out:
#            State   region  act_part_17
# 24     Minnesota  Midwest         1.00
# 26      Missouri  Midwest         1.00
# 50     Wisconsin  Midwest         1.00
# 35  North Dakota  Midwest         0.98
# 14      Illinois  Midwest         0.93
# 28      Nebraska  Midwest         0.84
# 42  South Dakota  Midwest         0.80
# 36          Ohio  Midwest         0.75
# 17        Kansas  Midwest         0.73
# 16          Iowa  Midwest         0.67
# 15       Indiana  Midwest         0.35
# 23      Michigan  Midwest         0.29
#
#
#            State   region  act_part_18
# 26      Missouri  Midwest         1.00
# 28      Nebraska  Midwest         1.00
# 36          Ohio  Midwest         1.00
# 50     Wisconsin  Midwest         1.00
# 24     Minnesota  Midwest         0.99
# 35  North Dakota  Midwest         0.98
# 42  South Dakota  Midwest         0.77
# 17        Kansas  Midwest         0.71
# 16          Iowa  Midwest         0.68
# 14      Illinois  Midwest         0.43
# ...

# %% [markdown]
# #### Summary of ACT Participation between 2017 and 2019

# %%
# States with consecutive 100% ACT partipation:
df.loc[(df['act_part_17']==1) & (df['act_part_18']==1) &(df['act_part_19']==1),['State','region']].sort_values('region')
# Out:
#              State   region
# 50       Wisconsin  Midwest
# 1          Alabama    South
# 4         Arkansas    South
# 18        Kentucky    South
# 19       Louisiana    South
# 25     Mississippi    South
# 34  North Carolina    South
# 37        Oklahoma    South
# 43       Tennessee    South
# 27         Montana     West
# 29          Nevada     West
# 45            Utah     West
# 51         Wyoming     West

# %% [markdown]
# <font color = blue><p>
# - A total of 13 states have consecutive 100% participation in ACT, and a majority of them are Southern states

# %% [markdown]
# #### SAT Participation by Region over the Years

# %%
sat_part = ['sat_part_17','sat_part_18','sat_part_19']
regions = ['Midwest','West','Northeast','South']
for j in regions:    
    for i in sat_part:
        print(df.loc[df['region']==j,['State','region',i]].sort_values(i,ascending=False))
        print('\n')
# Out:
#            State   region  sat_part_17
# 23      Michigan  Midwest         1.00
# 15       Indiana  Midwest         0.63
# 36          Ohio  Midwest         0.12
# 14      Illinois  Midwest         0.09
# 17        Kansas  Midwest         0.04
# 24     Minnesota  Midwest         0.03
# 26      Missouri  Midwest         0.03
# 28      Nebraska  Midwest         0.03
# 42  South Dakota  Midwest         0.03
# 50     Wisconsin  Midwest         0.03
# 16          Iowa  Midwest         0.02
# 35  North Dakota  Midwest         0.02
#
#
#            State   region  sat_part_18
# 23      Michigan  Midwest         1.00
# 14      Illinois  Midwest         0.99
# 15       Indiana  Midwest         0.63
# 36          Ohio  Midwest         0.18
# 17        Kansas  Midwest         0.04
# 24     Minnesota  Midwest         0.04
# 26      Missouri  Midwest         0.04
# 16          Iowa  Midwest         0.03
# 28      Nebraska  Midwest         0.03
# 42  South Dakota  Midwest         0.03
# ...

# %% [markdown]
# #### Summary of SAT Participation between 2017 and 2019

# %% [markdown]
# <font color = 'blue'><p>
# - 100% SAT participation is rather sparse in the states, with only 3 states having consecutive 100% participation between 2017 and 2019

# %%
# States with consecutive 100% SAT partipation:
df.loc[(df['sat_part_17']==1.0) & (df['sat_part_18']==1.0) &(df['sat_part_19']==1.0),['State','region']].sort_values('region')
# A total of 3 states have consecutive 100% participation in SAT
# Out:
#           State     region
# 23     Michigan    Midwest
# 7   Connecticut  Northeast
# 8      Delaware      South

# %%
# Check for 80% or more participation instead, since not a lot of states have 100% SAT participation implemented:
df.loc[(df['sat_part_17']>=.8) & (df['sat_part_18']>=.8) &(df['sat_part_19']>=.8),['State','region']].sort_values('region')
# Northeast States have 3 states with high SAT participation
# Out:
#             State     region
# 23       Michigan    Midwest
# 7     Connecticut  Northeast
# 20          Maine  Northeast
# 30  New Hampshire  Northeast
# 8        Delaware      South
# 13          Idaho       West

# %% [markdown]
# #### Summary of Participation and Scores by Region

# %%
df.groupby('region').mean().round(2).T
# Out:
# region        Midwest  Northeast    South     West
# act_part_17      0.78       0.25     0.76     0.71
# act_comp_17     21.63      24.42    20.47    20.49
# act_part_18      0.76       0.21     0.75     0.63
# act_comp_18     21.53      24.47    20.33    20.68
# act_part_19      0.72       0.18     0.71     0.62
# act_comp_19     21.50      24.60    20.28    20.56
# sat_part_17      0.17       0.78     0.36     0.34
# sat_total_17  1205.00    1063.00  1113.19  1126.38
# sat_part_18      0.26       0.85     0.38     0.43
# sat_total_18  1196.83    1071.11  1117.44  1097.15
# sat_part_19      0.26       0.86     0.48     0.43
# sat_total_19  1189.33    1063.89  1090.62  1115.00

# %%
print(df[['act_comp_17','act_comp_18','act_comp_19','sat_total_17','sat_total_18','sat_total_19']].mean().round(2).T)
act_score_mean = np.mean([df.act_comp_17, df.act_comp_18, df.act_comp_19])
sat_score_mean = np.mean([df.sat_total_17, df.sat_total_18, df.sat_total_19])
print('\n')
print(f'Mean ACT Composite score is {act_score_mean} out of 36')
print(f'Mean SAT Total score is {sat_score_mean} out of 1,600')
# Out:
# act_comp_17       21.47
# act_comp_18       21.45
# act_comp_19       21.42
# sat_total_17    1129.62
# sat_total_18    1122.88
# sat_total_19    1115.84
# dtype: float64
#
#
# Mean ACT Composite score is 21.448 out of 36
# Mean SAT Total score is 1122.78 out of 1,600

# %% [markdown]
# ### Summary Description of Data
# <font color = 'blue'><p>
# - From the observed data above, we can conclude that ACT participation are higher in the West, Midwest and South, while participation is low in the Northeast. ACT participation is also dropping all across the regions with each successive year.
#
# - On the other hand, SAT participation is high in the Northeast. The mean participation rate of SAT appears to be inversely proportionate to the participation rate of ACT. As opposed to ACT participation, SAT participation is generally increasing across all regions with each successive year.
#
# - ACT composite scores across the last 3 years are consistent with the means averaging at 21.5, against total of 36. There is a marginal drop in the mean composite scores in successive years.
#
# - SAT total scores across the last 3 years are quite consistent, averaging around 1123 out of a possible 1600. SAT scores are also dropping across all regions with each successive year.</font>

# %% [markdown]
# ### Meanwhile in the Midwest

# %%
# since ACT is the more dominant standardized test, let us have a look at it:
df_act = df.loc[df['region']=='Midwest'].drop(columns=['region','sat_total_17','sat_total_18','sat_total_19','sat_part_17','sat_part_18','sat_part_19'])
df_act['act_comp_mean'] = round((df.act_comp_17 + df.act_comp_18 + df.act_comp_19)/3,1)
df_act['act_part_mean'] = round((df.act_part_17 + df.act_part_18 + df.act_part_19)/3,2)
df_act[['State','act_part_17','act_part_18','act_part_19','act_part_mean','act_comp_17','act_comp_18','act_comp_19','act_comp_mean']]
# Out:
#            State  act_part_17  act_part_18  act_part_19  act_part_mean  \
# 14      Illinois         0.93         0.43         0.35           0.57
# 15       Indiana         0.35         0.32         0.29           0.32
# 16          Iowa         0.67         0.68         0.66           0.67
# 17        Kansas         0.73         0.71         0.72           0.72
# 23      Michigan         0.29         0.22         0.19           0.23
# 24     Minnesota         1.00         0.99         0.95           0.98
# 26      Missouri         1.00         1.00         0.82           0.94
# 28      Nebraska         0.84         1.00         1.00           0.95
# 35  North Dakota         0.98         0.98         0.96           0.97
# 36          Ohio         0.75         1.00         1.00           0.92
# 42  South Dakota         0.80         0.77         0.75           0.77
# 50     Wisconsin         1.00         1.00         1.00           1.00
#
# ...

# %% [markdown]
# <font color = blue><p>
# - Immediately right off the bat, something has happened in Illinois. ACT participation drastically drops by 50% between 2017 and 2018. This is probably attributed to the state policy making ACT optional. On the other hand, SAT participation rate of Illinois has drastically increased as shown below
# - Contrary to the general trend, Nebraska has increased state participation to 100%. This is due to the enactment of **NSCAS Act** that mandates all high schools to administer ACT
# - Ohio has also seen an increase from 75% to 100% ACT participation. This is due to the state making schools adopt ACT or SAT as the standardized test. Despite having this option, Ohio appears to favour ACT as shown against the SAT participation rates below
# - Wisconsin, Minnesota and North Dakota has state requirements to participate in ACT, however, their participation rate, with the exception of Wisconsin, is not 100%

# %%
df_sat = df.loc[df['region']=='Midwest'].drop(columns=['region','act_part_17','act_part_18','act_part_18','act_comp_17','act_comp_18','act_comp_19'])
df_sat['sat_total_mean'] = round((df.sat_total_17 + df.sat_total_18 + df.sat_total_19)/3,0)
df_sat['sat_part_mean'] = round((df.sat_part_17 + df.sat_part_18 + df.sat_part_19)/3,2)
df_sat[['State', 'sat_part_17','sat_part_18','sat_part_19','sat_part_mean','sat_total_17','sat_total_18','sat_total_19','sat_total_mean']]
# Out:
#            State  sat_part_17  sat_part_18  sat_part_19  sat_part_mean  \
# 14      Illinois         0.09         0.99         1.00           0.69
# 15       Indiana         0.63         0.63         0.66           0.64
# 16          Iowa         0.02         0.03         0.03           0.03
# 17        Kansas         0.04         0.04         0.04           0.04
# 23      Michigan         1.00         1.00         1.00           1.00
# 24     Minnesota         0.03         0.04         0.04           0.04
# 26      Missouri         0.03         0.04         0.04           0.04
# 28      Nebraska         0.03         0.03         0.03           0.03
# 35  North Dakota         0.02         0.02         0.02           0.02
# 36          Ohio         0.12         0.18         0.19           0.16
# 42  South Dakota         0.03         0.03         0.03           0.03
# 50     Wisconsin         0.03         0.03         0.03           0.03
#
# ...

# %% [markdown]
# <font color = blue><p>
# - SAT participation of Illinois skyrocketed in 2018 from 9% in the previous year to 99% in 2018
# - Michigan traditionally has SAT as the state mandated test
# - Ohio SAT participation increased by 7% over 2 years (perhaps some schools enforce both ACT and SAT participation?)

# %% [markdown]
# ## Visualize the Data
#
# There's not a magic bullet recommendation for the right number of plots to understand a given dataset, but visualizing your data is *always* a good idea. Not only does it allow you to quickly convey your findings (even if you have a non-technical audience), it will often reveal trends in your data that escaped you when you were looking only at numbers. It is important to not only create visualizations, but to **interpret your visualizations** as well.
#
# **Every plot should**:
# - Have a title
# - Have axis labels
# - Have appropriate tick labels
# - Text is legible in a plot
# - Plots demonstrate meaningful and valid relationships
# - Have an interpretation to aid understanding
#
# Here is an example of what your plots should look like following the above guidelines. Note that while the content of this example is unrelated, the principles of visualization hold:
#
# ![](https://snag.gy/hCBR1U.jpg)
# *Interpretation: The above image shows that as we increase our spending on advertising, our sales numbers also tend to increase. There is a positive correlation between advertising spending and sales.*
#
# ---
#
# Here are some prompts to get you started with visualizations. Feel free to add additional visualizations as you see fit:
# 1. Use Seaborn's heatmap with pandas `.corr()` to visualize correlations between all numeric features.
#     - Heatmaps are generally not appropriate for presentations, and should often be excluded from reports as they can be visually overwhelming. **However**, they can be extremely useful in identify relationships of potential interest (as well as identifying potential collinearity before modeling).
#     - Please take time to format your output, adding a title. Look through some of the additional arguments and options. (Axis labels aren't really necessary, as long as the title is informative).
# 2. Visualize distributions using histograms. If you have a lot, consider writing a custom function and use subplots.
#     - *OPTIONAL*: Summarize the underlying distributions of your features (in words & statistics)
#          - Be thorough in your verbal description of these distributions.
#          - Be sure to back up these summaries with statistics.
#          - We generally assume that data we sample from a population will be normally distributed. Do we observe this trend? Explain your answers for each distribution and how you think this will affect estimates made from these data.
# 3. Plot and interpret boxplots.
#     - Boxplots demonstrate central tendency and spread in variables. In a certain sense, these are somewhat redundant with histograms, but you may be better able to identify clear outliers or differences in IQR, etc.
#     - Multiple values can be plotted to a single boxplot as long as they are of the same relative scale (meaning they have similar min/max values).
#     - Each boxplot should:
#         - Only include variables of a similar scale
#         - Have clear labels for each variable
#         - Have appropriate titles and labels
# 4. Plot and interpret scatter plots to view relationships between features. Feel free to write a custom function, and subplot if you'd like. Functions save both time and space.
#     - Your plots should have:
#         - Two clearly labeled axes
#         - A proper title
#         - Colors and symbols that are clear and unmistakable
# 5. Additional plots of your choosing.
#     - Are there any additional trends or relationships you haven't explored? Was there something interesting you saw that you'd like to dive further into? It's likely that there are a few more plots you might want to generate to support your narrative and recommendations that you are building toward. **As always, make sure you're interpreting your plots as you go**.

# %%
act_part = ['act_part_17','act_part_18','act_part_19']
sat_part = ['sat_part_17','sat_part_18','sat_part_19']
sat_total = ['sat_total_17', 'sat_total_18','sat_total_19']
act_comp = ['act_comp_17','act_comp_18','act_comp_19']
act_part_label = ['ACT Participation 2017','ACT Participation 2018','ACT Participation 2019']
sat_part_label =['SAT Participation 2017','SAT Participation 2018','SAT Participation 2019']
act_comp_label =['ACT Composite Score 2017','ACT Composite Score 2018','ACT Composite Score 2019']
sat_total_label =['SAT Total Score 2017','SAT Total Score 2018','SAT Total Score 2019']

# %%
plt.figure(figsize=(16, 9))
plt.title('Correlation Heatmap',size=18)
sns.heatmap(df.corr(),annot=True,vmin=-1,vmax=1,square=True,linewidth=0.5,cmap="GnBu");

# %%
def plotline(list_of_variables,state):
    list_=[]
    for i in list_of_variables:
        list_.append(df.loc[df['State']==state][i])
    return list_

# %%
x=['2017','2018','2019']
fig, ax = plt.subplots(3,4,sharey=True)
fig.suptitle("ACT & SAT Participation by Midwestern States",size=20)
ax= ax.ravel()
for i in range(12):
    ax[i].plot(x,plotline(act_part,midwest[i]),label='ACT',linewidth=2)
    ax[i].plot(x,plotline(sat_part,midwest[i]),label='SAT',linewidth=2)
    ax[i].title.set_text(midwest[i])
    ax[i].set_ylim([0,1.15])
    for j,k in zip(x,plotline(act_part,midwest[i])):
        ax[i].annotate(float(k),(j,k),rotation=90,va='bottom',color='r')
    for j,k in zip(x,plotline(sat_part,midwest[i])):
        ax[i].annotate(float(k),(j,k),rotation=90,va='bottom',color='b')

fig.set_figheight(10)
fig.set_figwidth(15)
fig.tight_layout()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc = 'right');

# %%
fig, ax = plt.subplots(3,4,sharey=True)
fig.suptitle("ACT Scores by Midwestern States",size=20)
ax= ax.ravel()
for i in range(12):
    ax[i].plot(x,plotline(act_comp,midwest[i]),label='ACT Score',linewidth=2)
    ax[i].title.set_text(midwest[i])
    ax[i].set_ylim([0,27])
    for j,k in zip(x,plotline(act_comp,midwest[i])):
        ax[i].annotate(float(k),(j,k),va='top',rotation=90,color='red')

fig.set_figheight(10)
fig.set_figwidth(15)
fig.tight_layout()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels,loc = 'right');

# %%
fig, ax = plt.subplots(3,4,sharey=True)
fig.suptitle("SAT Scores by Midwestern States",size=20)
ax= ax.ravel()
for i in range(12):
    ax[i].plot(x,plotline(sat_total,midwest[i]),label='SAT Score',color='orange',linewidth=2)
    ax[i].title.set_text(midwest[i])
    ax[i].set_ylim([0,1600])
    for j,k in zip(x,plotline(sat_total,midwest[i])):
        ax[i].annotate(int(k),(j,k),rotation=90,color='b',va='top')

fig.set_figheight(10)
fig.set_figwidth(15)
fig.tight_layout()

lines, labels = fig.axes[-1].get_legend_handles_labels()
fig.legend(lines, labels, loc = 'right');

# %%
def scatter(x,y,xindex,yindex,xlabel,ylabel):
    plt.figure(figsize=(12, 8))
    for i in range(3):
        plt.subplot(3,1,i+1)
        plt.tight_layout()
        m, b = np.polyfit(x[xindex[i]], y[yindex[i]], 1)
        plt.xlim(0,1)
        plt.scatter( x[xindex[i]], y[yindex[i]], color = 'b')
        plt.plot(x[xindex[i]], m* x[xindex[i]] + b, color='orange',alpha=0.5, linewidth=3)
        plt.xlabel(xlabel[i])
        plt.xlim([0,1.1])
        plt.ylabel(ylabel[i]);
        plt.title(f'{ylabel[i]} vs {xlabel[i]}')

# %%
scatter(df_act[act_part],df_act[act_comp],act_part,act_comp,act_part_label,act_comp_label)

# %%
scatter(df_sat[sat_part],df_sat[sat_total],sat_part,sat_total,sat_part_label,sat_total_label)

# %% [markdown]
# <font color = blue><p>
# - As shown by the two graphs above, both show a negative correlation between participation and scores, and this is consistent across the years. However, as the midwest only consists of 12 states, this may not be enough. Therefore we will compare it against all 50 states

# %%
scatter(df[act_part],df[act_comp],act_part,act_comp,act_part_label,act_comp_label)

# %%
scatter(df[sat_part],df[sat_total],sat_part,sat_total,sat_part_label,sat_total_label)

# %% [markdown]
# <font color = blue><p>
# - There is indeed a general negative correlation between participation and scores, regardless of the test type. This may be attributed that for states with lower participation, only students who are highly motivated would participate, while students who are forced to take part in the test may not be as motivated.

# %%
scatter(df.loc[df['region']=='Midwest'][sat_part],df.loc[df['region']=='Midwest'][act_part],sat_part,act_part,sat_part_label,act_part_label)

# %% [markdown]
# <font color = blue><p>
# - And finally, as shown above, there is a negative correlation between SAT and ACT.
# - The visualization of the participation datas also show that while ACT has a higher number of states having 100%, SAT has even more number of states having 50% and higher participation rate.

# %%
x = ['2017', '2018', '2019']  
all_act=[]
all_sat=[]
midwest_act = []
midwest_sat = []
west_act = []
west_sat = []
northeast_act = []
northeast_sat = []
south_act = []
south_sat = []
plot_list = [all_act,all_sat,midwest_act,midwest_sat,west_act,west_sat,northeast_act,northeast_sat,south_act,south_sat]
plot_labels = ['All ACT','ALL SAT','ACT - Midwest','SAT - Midwest','ACT - West','SAT - West','ACT - Northeast','SAT - Northeast','ACT - South','SAT - South']
colors = ['#000000','#000000','#FF0000','#FF0000','#13FF00','#13FF00','#0038FF','#0038FF','#FFA900','#FFA900']
markers = ['s','x','*','^','o']*2

for i in act_part:
    all_act.append(df[i].sum()/50)
    midwest_act.append(df.loc[df['region']=='Midwest',i].sum()/len(midwest))
    west_act.append(df.loc[df['region']=='West',i].sum()/len(west))
    northeast_act.append(df.loc[df['region']=='Northeast',i].sum()/len(northeast))
    south_act.append(df.loc[df['region']=='South',i].sum()/len(south))

for i in sat_part:
    all_sat.append(df[i].sum()/50)
    midwest_sat.append(df.loc[df['region']=='Midwest',i].sum()/len(midwest))
    west_sat.append(df.loc[df['region']=='West',i].sum()/len(west))
    northeast_sat.append(df.loc[df['region']=='Northeast',i].sum()/len(northeast))
    south_sat.append(df.loc[df['region']=='South',i].sum()/len(south))

# %%
plt.figure(figsize=(16,12))
for i in range(len(plot_list)):
    plt.plot(x,plot_list[i],color=colors[i],label=plot_labels[i],marker=markers[i],markersize=10,alpha=0.5)
plt.title('ACT & SAT Participation over the years', size=18)
plt.xlabel('Year',size=15)
plt.ylim([0,1])
plt.ylabel('Participation Rate',size=15)
plt.legend(title='title', bbox_to_anchor=(1.05, 1), loc='upper left');

# %% [markdown]
# ## Conclusions and Recommendations

# %% [markdown]
# Based on your exploration of the data, what are you key takeaways and recommendations? Make sure to answer your question of interest or address your problem statement here.

# %% [markdown]
# ### Conclusion
# <font color = blue><p>
# - While 100% ACT or SAT participation are typically attributed to state policies, it would appear that SAT is the preferred test for schools or students who have the option between the two standardized tests.
# - Furthermore with the trend that ACT participation continues to drop over the years while SAT participation continues to increase over the years show that there is a general shift towards SAT as the choice standardized test. This may be attributed to the revision of the SAT in 2016.

# %% [markdown]
# ### Recommendation
# <font color = blue><p>
# - For SAT: The increased participation over 2 years is evident that the strategy in place is in good order. As long as SAT maintains its standards and implementations, we can expect it to gain popularity
# - For ACT: While the ACT has had a better hold over several states, it is losing ground in other states where it is optional. The decline of ACT maybe a signal for a review of the test. Perhaps providing additional services such as giving subscore breakdowns may help.
# -  Overall, due to the inverse relationship of ACT and SAT participation, the total participation rate does not have any major flunctuations. In order to improve participation rates overall the simplest solution is for states to mandate 100% participation in one of the two tests. Naturally, this is not feasible, at least not without a great amount of work. Therefore, in the short term, it might be better to:
#     - Allow SAT and ACT to branch out into more specialized subjects that is significantly diverse from each other and therefore,
#     - Allow students to pick which of the test is more tailored to their needs
#     - This in turn would allow universities to vary their entry requirements based on the type of test needed for each major
#
#     <br>
# - For Midwest: It seems that even though ACT participation continues to decline in this region, SAT participation rates are not proportionally increasing for 8 out of the 12 states. Other than Ohio and Illinois, the rest of the states are rather stagnant in terms of SAT pickup. It would be in the best interest for SAT college board to promote SAT in this region as ACT participation is in decline, while there are plenty of potential of growth in terms of SAT participation.

# %% [markdown]
# Don't forget to create your README!
#
# **To-Do:** *If you combine your problem statement, data dictionary, brief summary of your analysis, and conclusions/recommendations, you have an amazing README.md file that quickly aligns your audience to the contents of your project.* Don't forget to cite your data sources!
